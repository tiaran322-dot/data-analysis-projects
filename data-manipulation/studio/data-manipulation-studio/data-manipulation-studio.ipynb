# %% [markdown]
# # Data Manipulation Studio
#
# For this studio, we will revisit the data set from our last studio. If you recall, California farmers were looking for advice on growing pumpkins. We will use the same [pumpkins dataset](https://www.kaggle.com/usda/a-year-of-pumpkin-prices) as provided by the U.S. Department of Agriculture. You may have to clean data in the process of data manipulation, so feel free to pull up your notebook from the last class's studio.
#
# We will now be focusing our attention on a different region in the United States, the Northeast. When you open up the `dataset` folder, you will have 13 CSVs, including the San Francisco and Los Angeles data from the last lesson. The 13 CSVs are each a different terminal market in the United States.
#
# A **terminal market** is a central site, often in a metropolitan area, that serves as an assembly and trading place for commodities. Terminal markets for agricultural commodities are usually at or near major transportation hubs. [Definition Source](https://en.wikipedia.org/wiki/Terminal_market#:~:text=A%20terminal%20market%20is%20a,or%20near%20major%20transportation%20hubs)
#
# ## Getting Started
#
# Import the CSVs for each of the following cities: Baltimore, Boston, New York, and Philadelphia. Set up a dataframe for each city.

# %%
# Import the necessary libraries and CSVs. Make some dataframes!
import pandas as pd
import numpy as np

baltimore = pd.read_csv("/Users/tiaranicole/LCGithub/data-analysis-projects/data-manipulation/studio/data-manipulation-studio/dataset/baltimore_9-24-2016_9-30-2017.csv")
boston = pd.read_csv("/Users/tiaranicole/LCGithub/data-analysis-projects/data-manipulation/studio/data-manipulation-studio/dataset/boston_9-24-2016_9-30-2017.csv")
newyork = pd.read_csv('/Users/tiaranicole/LCGithub/data-analysis-projects/data-manipulation/studio/data-manipulation-studio/dataset/new-york_9-24-2016_9-30-2017.csv')
philly = pd.read_csv('/Users/tiaranicole/LCGithub/data-analysis-projects/data-manipulation/studio/data-manipulation-studio/dataset/philadelphia_9-24-2016_9-30-2017.csv')

# %% [markdown]
# ## Clean Your Data
#
# In the last lesson, we cleaned the data related to San Francisco. Pull up your notebook from the last lesson and use it as a reference to clean up these new dataframes.

# %%
# Clean your data here!
for col in baltimore.columns:
    pct_missing = np.mean(baltimore[col].isnull())
    print('{} - {}%'.format(col, round(pct_missing*100)))
# Out:
# Commodity Name - 0%
# City Name - 0%
# Type - 100%
# Package - 0%
# Variety - 1%
# Sub Variety - 84%
# Grade - 100%
# Date - 0%
# Low Price - 0%
# High Price - 0%
# Mostly Low - 0%
# Mostly High - 0%
# Origin - 3%
# Origin District - 100%
# Item Size - 16%
# Color - 80%
# Environment - 100%
# Unit of Sale - 84%
# Quality - 100%
# Condition - 100%
# Appearance - 100%
# Storage - 100%
# Crop - 100%
# Repack - 0%
# Trans Mode - 100%

# %%
baltimore = baltimore.drop(columns=["Grade","Mostly Low", "Mostly High"])

# %%
baltimore.head()
# Out:
#   Commodity Name  City Name  Type       Package      Variety Sub Variety  \
# 0       PUMPKINS  BALTIMORE   NaN  24 inch bins          NaN         NaN
# 1       PUMPKINS  BALTIMORE   NaN  24 inch bins          NaN         NaN
# 2       PUMPKINS  BALTIMORE   NaN  24 inch bins  HOWDEN TYPE         NaN
# 3       PUMPKINS  BALTIMORE   NaN  24 inch bins  HOWDEN TYPE         NaN
# 4       PUMPKINS  BALTIMORE   NaN  24 inch bins  HOWDEN TYPE         NaN
#
#          Date  Low Price  High Price    Origin  ...  Color Environment  \
# 0  04/29/2017        270       280.0       NaN  ...    NaN         NaN
# 1  05/06/2017        270       280.0       NaN  ...    NaN         NaN
# 2  09/24/2016        160       160.0  DELAWARE  ...    NaN         NaN
# 3  09/24/2016        160       160.0  VIRGINIA  ...    NaN         NaN
# 4  11/05/2016         90       100.0  MARYLAND  ...    NaN         NaN
#
#   Unit of Sale  Quality Condition  Appearance  Storage  Crop  Repack  \
# 0          NaN      NaN       NaN         NaN      NaN   NaN       E
# 1          NaN      NaN       NaN         NaN      NaN   NaN       E
# 2          NaN      NaN       NaN         NaN      NaN   NaN       N
# 3          NaN      NaN       NaN         NaN      NaN   NaN       N
# 4          NaN      NaN       NaN         NaN      NaN   NaN       N
#
#    Trans Mode
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
#
# [5 rows x 22 columns]

# %%
philly.head()
# Out:
#   Commodity Name     City Name  Type       Package      Variety Sub Variety  \
# 0       PUMPKINS  PHILADELPHIA   NaN  24 inch bins  HOWDEN TYPE         NaN
# 1       PUMPKINS  PHILADELPHIA   NaN  36 inch bins  HOWDEN TYPE         NaN
# 2       PUMPKINS  PHILADELPHIA   NaN  36 inch bins  HOWDEN TYPE         NaN
# 3       PUMPKINS  PHILADELPHIA   NaN  36 inch bins  HOWDEN TYPE         NaN
# 4       PUMPKINS  PHILADELPHIA   NaN  36 inch bins  HOWDEN TYPE         NaN
#
#          Date  Low Price  High Price        Origin  ...  Color Environment  \
# 0  09/16/2017        140         150  PENNSYLVANIA  ...    NaN         NaN
# 1  09/24/2016        150         150      NEW YORK  ...    NaN         NaN
# 2  09/24/2016        150         150      NEW YORK  ...    NaN         NaN
# 3  09/24/2016        150         160  PENNSYLVANIA  ...    NaN         NaN
# 4  10/01/2016        140         140    NEW JERSEY  ...    NaN         NaN
#
#    Unit of Sale  Quality Condition  Appearance  Storage  Crop  Repack  \
# 0           NaN      NaN       NaN         NaN      NaN   NaN       N
# 1           NaN      NaN       NaN         NaN      NaN   NaN       N
# 2           NaN      NaN       NaN         NaN      NaN   NaN       N
# 3           NaN      NaN       NaN         NaN      NaN   NaN       N
# 4           NaN      NaN       NaN         NaN      NaN   NaN       N
#
#    Trans Mode
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
#
# [5 rows x 22 columns]

# %%
newyork = newyork.drop(columns=["Grade","Mostly Low", "Mostly High"])

newyork.head()
# Out:
#   Commodity Name City Name  Type       Package      Variety Sub Variety  \
# 0       PUMPKINS  NEW YORK   NaN  36 inch bins  HOWDEN TYPE         NaN
# 1       PUMPKINS  NEW YORK   NaN  36 inch bins  HOWDEN TYPE         NaN
# 2       PUMPKINS  NEW YORK   NaN  36 inch bins  HOWDEN TYPE         NaN
# 3       PUMPKINS  NEW YORK   NaN  36 inch bins  HOWDEN TYPE         NaN
# 4       PUMPKINS  NEW YORK   NaN  36 inch bins  HOWDEN TYPE         NaN
#
#          Date  Low Price  High Price      Origin  ... Color Environment  \
# 0  09/24/2016        150         170    MICHIGAN  ...   NaN         NaN
# 1  09/24/2016        150         170    MICHIGAN  ...   NaN         NaN
# 2  09/24/2016        130         150  NEW JERSEY  ...   NaN         NaN
# 3  09/24/2016        130         150  NEW JERSEY  ...   NaN         NaN
# 4  09/24/2016        120         140    NEW YORK  ...   NaN         NaN
#
#   Unit of Sale  Quality Condition  Appearance  Storage  Crop  Repack  \
# 0          NaN      NaN       NaN         NaN      NaN   NaN       N
# 1          NaN      NaN       NaN         NaN      NaN   NaN       N
# 2          NaN      NaN       NaN         NaN      NaN   NaN       N
# 3          NaN      NaN       NaN         NaN      NaN   NaN       N
# 4          NaN      NaN       NaN         NaN      NaN   NaN       N
#
#    Trans Mode
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
#
# [5 rows x 22 columns]

# %%
boston = boston.drop(columns=["Grade","Mostly Low", "Mostly High"])

boston.head()
# Out:
#   Commodity Name City Name  Type       Package      Variety Sub Variety  \
# 0       PUMPKINS    BOSTON   NaN  36 inch bins  HOWDEN TYPE         NaN
# 1       PUMPKINS    BOSTON   NaN  36 inch bins  HOWDEN TYPE         NaN
# 2       PUMPKINS    BOSTON   NaN  36 inch bins  HOWDEN TYPE         NaN
# 3       PUMPKINS    BOSTON   NaN  36 inch bins  HOWDEN TYPE         NaN
# 4       PUMPKINS    BOSTON   NaN  36 inch bins  HOWDEN TYPE         NaN
#
#          Date  Low Price  High Price  Origin  ...   Color Environment  \
# 0  09/24/2016        160         200  CANADA  ...  ORANGE         NaN
# 1  09/24/2016        160         200  CANADA  ...  ORANGE         NaN
# 2  09/24/2016        160         200  CANADA  ...  ORANGE         NaN
# 3  09/24/2016        160         200  CANADA  ...  ORANGE         NaN
# 4  09/24/2016        160         180  CANADA  ...  ORANGE         NaN
#
#   Unit of Sale  Quality Condition  Appearance  Storage  Crop  Repack  \
# 0          NaN      NaN       NaN         NaN      NaN   NaN       N
# 1          NaN      NaN       NaN         NaN      NaN   NaN       N
# 2          NaN      NaN       NaN         NaN      NaN   NaN       N
# 3          NaN      NaN       NaN         NaN      NaN   NaN       N
# 4          NaN      NaN       NaN         NaN      NaN   NaN       N
#
#    Trans Mode
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
#
# [5 rows x 22 columns]

# %% [markdown]
# ## Combine Your Data
#
# Now that you have four clean sets of data, combine all four into one dataframe that represents the entire Northeast region.

# %%
# Combine the four dataframes into one!
NEpumpkins = pd.concat([baltimore, boston, philly, newyork], ignore_index=True)

NEpumpkins.sample(25)
# Out:
#     Commodity Name  City Name  Type               Package        Variety  \
# 71        PUMPKINS  BALTIMORE   NaN  1 1/9 bushel cartons       PIE TYPE
# 372       PUMPKINS     BOSTON   NaN          36 inch bins       PIE TYPE
# 69        PUMPKINS  BALTIMORE   NaN          24 inch bins      FAIRYTALE
# 293       PUMPKINS     BOSTON   NaN          24 inch bins     CINDERELLA
# 102       PUMPKINS  BALTIMORE   NaN          24 inch bins  BIG MACK TYPE
# 80        PUMPKINS  BALTIMORE   NaN  1 1/9 bushel cartons       PIE TYPE
# 97        PUMPKINS  BALTIMORE   NaN          24 inch bins  BIG MACK TYPE
# 326       PUMPKINS     BOSTON   NaN   1 1/9 bushel crates       PIE TYPE
# 266       PUMPKINS     BOSTON   NaN          36 inch bins    HOWDEN TYPE
# 164       PUMPKINS     BOSTON   NaN          36 inch bins    HOWDEN TYPE
# 249       PUMPKINS     BOSTON   NaN          36 inch bins    HOWDEN TYPE
# 628       PUMPKINS   NEW YORK   NaN          24 inch bins       PIE TYPE
# 589       PUMPKINS   NEW YORK   NaN          36 inch bins    HOWDEN TYPE
# 31        PUMPKINS  BALTIMORE   NaN          24 inch bins     CINDERELLA
# 91        PUMPKINS  BALTIMORE   NaN  1 1/9 bushel cartons       PIE TYPE
# 356       PUMPKINS     BOSTON   NaN          24 inch bins       PIE TYPE
# 287       PUMPKINS     BOSTON   NaN          24 inch bins     CINDERELLA
# 442       PUMPKINS     BOSTON   NaN          24 inch bins   KNUCKLE HEAD
# 440       PUMPKINS     BOSTON   NaN          24 inch bins      BLUE TYPE
# 619       PUMPKINS   NEW YORK   NaN          24 inch bins       PIE TYPE
# 661       PUMPKINS   NEW YORK   NaN   1 1/9 bushel crates      MINIATURE
# 181       PUMPKINS     BOSTON   NaN          36 inch bins    HOWDEN TYPE
# 288       PUMPKINS     BOSTON   NaN          24 inch bins     CINDERELLA
# 267       PUMPKINS     BOSTON   NaN          36 inch bins    HOWDEN TYPE
# 35        PUMPKINS  BALTIMORE   NaN          24 inch bins     CINDERELLA
#
#     Sub Variety        Date  Low Price  High Price         Origin  ...  \
# 71          NaN  09/24/2016         18        18.0       DELAWARE  ...
# 372         NaN  09/24/2016        180       225.0   PENNSYLVANIA  ...
# 69          NaN  11/26/2016        210       210.0       VIRGINIA  ...
# 293         NaN  10/22/2016        260       285.0  MASSACHUSETTS  ...
# 102         NaN  10/08/2016         50        60.0       MARYLAND  ...
# 80          NaN  10/15/2016         17        18.5   PENNSYLVANIA  ...
# 97          NaN  09/24/2016         50        60.0       MARYLAND  ...
# 326         NaN  11/05/2016         15        16.0  MASSACHUSETTS  ...
# 266         NaN  10/29/2016        140       160.0   PENNSYLVANIA  ...
# 164         NaN  09/24/2016        180       225.0  MASSACHUSETTS  ...
# 249         NaN  10/29/2016        160       200.0         CANADA  ...
# 628         NaN  09/30/2017        140       140.0   PENNSYLVANIA  ...
# 589         NaN  09/16/2017        140       160.0     NEW JERSEY  ...
# 31          NaN  06/17/2017        380       380.0            NaN  ...
# 91          NaN  09/30/2017         16        16.0       DELAWARE  ...
# 356         NaN  10/22/2016        150       175.0  MASSACHUSETTS  ...
# 287         NaN  10/01/2016        260       285.0  MASSACHUSETTS  ...
# 442         NaN  10/01/2016        260       285.0  MASSACHUSETTS  ...
# 440         NaN  11/05/2016        260       285.0  MASSACHUSETTS  ...
# 619         NaN  09/09/2017        250       250.0   PENNSYLVANIA  ...
# 661         NaN  10/08/2016         18        18.0       NEW YORK  ...
# 181         NaN  10/01/2016        200       225.0  MASSACHUSETTS  ...
# 288         NaN  10/01/2016        260       285.0  MASSACHUSETTS  ...
# 267         NaN  11/05/2016        180       225.0  MASSACHUSETTS  ...
# 35          NaN  09/09/2017        180       180.0       MARYLAND  ...
#
#       Color Environment Unit of Sale  Quality Condition  Appearance  Storage  \
# 71      NaN         NaN          NaN      NaN       NaN         NaN      NaN
# 372  ORANGE         NaN          NaN      NaN       NaN         NaN      NaN
# 69      NaN         NaN          NaN      NaN       NaN         NaN      NaN
# 293   WHITE         NaN          NaN      NaN       NaN         NaN      NaN
# 102     NaN         NaN         EACH      NaN       NaN         NaN      NaN
# 80      NaN         NaN          NaN      NaN       NaN         NaN      NaN
# 97      NaN         NaN         EACH      NaN       NaN         NaN      NaN
# 326  ORANGE         NaN          NaN      NaN       NaN         NaN      NaN
# 266  ORANGE         NaN          NaN      NaN       NaN         NaN      NaN
# 164  ORANGE         NaN          NaN      NaN       NaN         NaN      NaN
# 249  ORANGE         NaN          NaN      NaN       NaN         NaN      NaN
# 628  ORANGE         NaN      PER BIN      NaN       NaN         NaN      NaN
# 589     NaN         NaN      PER BIN      NaN       NaN         NaN      NaN
# 31      NaN         NaN          NaN      NaN       NaN         NaN      NaN
# 91   ORANGE         NaN          NaN      NaN       NaN         NaN      NaN
# 356  ORANGE         NaN          NaN      NaN       NaN         NaN      NaN
# 287  ORANGE         NaN          NaN      NaN       NaN         NaN      NaN
# 442  ORANGE         NaN          NaN      NaN       NaN         NaN      NaN
# 440  ORANGE         NaN          NaN      NaN       NaN         NaN      NaN
# 619     NaN         NaN          NaN      NaN       NaN         NaN      NaN
# 661     NaN         NaN          NaN      NaN       NaN         NaN      NaN
# 181  ORANGE         NaN          NaN      NaN       NaN         NaN      NaN
# 288   WHITE         NaN          NaN      NaN       NaN         NaN      NaN
# 267  ORANGE         NaN          NaN      NaN       NaN         NaN      NaN
# 35      NaN         NaN          NaN      NaN       NaN         NaN      NaN
#
#      Crop  Repack  Trans Mode
# 71    NaN       N         NaN
# 372   NaN       N         NaN
# 69    NaN       N         NaN
# 293   NaN       N         NaN
# 102   NaN       N         NaN
# 80    NaN       N         NaN
# 97    NaN       N         NaN
# 326   NaN       N         NaN
# 266   NaN       N         NaN
# 164   NaN       N         NaN
# 249   NaN       N         NaN
# 628   NaN       N         NaN
# 589   NaN       N         NaN
# 31    NaN       E         NaN
# 91    NaN       N         NaN
# 356   NaN       N         NaN
# 287   NaN       N         NaN
# 442   NaN       N         NaN
# 440   NaN       N         NaN
# 619   NaN       N         NaN
# 661   NaN       N         NaN
# 181   NaN       N         NaN
# 288   NaN       N         NaN
# 267   NaN       N         NaN
# 35    NaN       N         NaN
#
# [25 rows x 22 columns]

# %% [markdown]
# ## Answer Some Questions
#
# Use `groupby()` and `agg()` to answer the following two questions:
#
# 1. What is the mean low and high prices for each type of **unit of sale** in the Northeast region?
# 2. For each region, what is the average number of pumpkins per variety that came into terminal markets for the year?

# %%
# Put your code here to find the mean low and high prices in the Northeast region for each type of unit of sale.
NE_avg_low_price = NEpumpkins["Low Price"].agg("mean")
NE_avg_high_price = NEpumpkins["High Price"].agg("mean")
print(NE_avg_low_price, NE_avg_high_price)
# Out:
# 134.18397626112758 150.6713649851632

# %%
NEpumpkins["Variety"].value_counts()
# Out:
# Variety
# HOWDEN TYPE                 224
# PIE TYPE                    198
# MINIATURE                    97
# BIG MACK TYPE                55
# CINDERELLA                   39
# FAIRYTALE                    37
# KNUCKLE HEAD                  9
# BLUE TYPE                     7
# MIXED HEIRLOOM VARIETIES      4
# HOWDEN WHITE TYPE             2
# Name: count, dtype: int64

# %%
# Put your code here to find the average number of pumpkins coming into terminal markets of each variety.
NEpumpkins.groupby(["City Name", "Variety"]).head()

#There are no numerical values other than price that I can get the average for. I don't understand how you can get an average pumpkin number without having some type of conversion for the packaging.
# Out:
#     Commodity Name  City Name  Type             Package      Variety  \
# 2         PUMPKINS  BALTIMORE   NaN        24 inch bins  HOWDEN TYPE
# 3         PUMPKINS  BALTIMORE   NaN        24 inch bins  HOWDEN TYPE
# 4         PUMPKINS  BALTIMORE   NaN        24 inch bins  HOWDEN TYPE
# 5         PUMPKINS  BALTIMORE   NaN        24 inch bins  HOWDEN TYPE
# 6         PUMPKINS  BALTIMORE   NaN        36 inch bins  HOWDEN TYPE
# ..             ...        ...   ...                 ...          ...
# 647       PUMPKINS   NEW YORK   NaN  1/2 bushel cartons    MINIATURE
# 648       PUMPKINS   NEW YORK   NaN  1/2 bushel cartons    MINIATURE
# 649       PUMPKINS   NEW YORK   NaN  1/2 bushel cartons    MINIATURE
# 650       PUMPKINS   NEW YORK   NaN  1/2 bushel cartons    MINIATURE
# 651       PUMPKINS   NEW YORK   NaN  1/2 bushel cartons    MINIATURE
#
#     Sub Variety        Date  Low Price  High Price    Origin  ...  Color  \
# 2           NaN  09/24/2016        160       160.0  DELAWARE  ...    NaN
# 3           NaN  09/24/2016        160       160.0  VIRGINIA  ...    NaN
# 4           NaN  11/05/2016         90       100.0  MARYLAND  ...    NaN
# 5           NaN  11/12/2016         90       100.0  MARYLAND  ...    NaN
# 6           NaN  09/24/2016        160       170.0  MARYLAND  ...    NaN
# ..          ...         ...        ...         ...       ...  ...    ...
# 647   FLAT TYPE  09/24/2016         15        18.0      OHIO  ...    NaN
# 648   FLAT TYPE  09/24/2016         20        20.0      OHIO  ...  WHITE
# 649   FLAT TYPE  10/01/2016         15        18.0      OHIO  ...    NaN
# 650   FLAT TYPE  10/01/2016         20        20.0      OHIO  ...  WHITE
# 651   FLAT TYPE  10/08/2016         18        18.0      OHIO  ...    NaN
#
#     Environment Unit of Sale  Quality Condition  Appearance  Storage  Crop  \
# 2           NaN          NaN      NaN       NaN         NaN      NaN   NaN
# 3           NaN          NaN      NaN       NaN         NaN      NaN   NaN
# 4           NaN          NaN      NaN       NaN         NaN      NaN   NaN
# 5           NaN          NaN      NaN       NaN         NaN      NaN   NaN
# 6           NaN          NaN      NaN       NaN         NaN      NaN   NaN
# ..          ...          ...      ...       ...         ...      ...   ...
# 647         NaN          NaN      NaN       NaN         NaN      NaN   NaN
# 648         NaN          NaN      NaN       NaN         NaN      NaN   NaN
# 649         NaN          NaN      NaN       NaN         NaN      NaN   NaN
# 650         NaN          NaN      NaN       NaN         NaN      NaN   NaN
# 651         NaN          NaN      NaN       NaN         NaN      NaN   NaN
#
#      Repack  Trans Mode
# 2         N         NaN
# 3         N         NaN
# 4         N         NaN
# 5         N         NaN
# 6         N         NaN
# ..      ...         ...
# 647       N         NaN
# 648       N         NaN
# 649       N         NaN
# 650       N         NaN
# 651       N         NaN
#
# [110 rows x 22 columns]

# %% [markdown]
# ## Bonus Mission
#
# Try answering the same questions for the Midwest (Chicago, Detroit, and St. Louis) or the Southeast (Atlanta, Columbia, and Miami) regions.

# %%
# Try the bonus mission if you have time!
